# %%
from splinter import Browser
from bs4 import BeautifulSoup as soup

# %%
browser = Browser("chrome")

# %%
url = "https://www.fangraphs.com/roster-resource/injury-report?season=2024&groupby=all&timeframe=all"

# %%
browser.visit(url)

# %%
html = browser.html

# %%
html_soup = soup(html, "html.parser")

# %%
browser.links.find_by_partial_text("Single Grid").click()

# %%
dropdown = browser.find_by_tag('select')

# %%
dropdown.select_by_text('Infinity')

# %%
tables = html_soup.find_all('table')

# %%
len(tables)
# Out:
# 16

# %%
rows = tables[15].find_all('tr')

# %%
headers = [x.text for x in rows[0].find_all('th')]

# %%
headers
# Out:
# ['Name',
#  'Team',
#  'Pos',
#  'Injury / Surgery Date',
#  'Injury / Surgery',
#  'Status',
#  'IL Retro Date',
#  'Eligible to Return',
#  'Return Date',
#  'Latest Update']

# %%
injury_table = []
for x in rows[1:]:
    injury_table.append([every_value.text for every_value in x.find_all("td")])

# %%
import pandas as pd
df = pd.DataFrame(injury_table, columns=headers)

# %%
# Initialize the DataFrame list
injury_table = []
# Loop through all pages
while True:
    # Parse the HTML
    html = browser.html
    html_soup = soup(html, "html.parser")
    
    # Find the table and rows
    tables = html_soup.find_all('table')
    rows = tables[15].find_all('tr')  # Adjust the index if necessary
    
    # Extract headers and data
    if len(injury_table) == 0:
        headers = [x.text for x in rows[0].find_all('th')]
    
    for row in rows[1:]:
        injury_table.append([val.text for val in row.find_all("td")])
    
    # Check if there's a "Next" button and click it, otherwise break
    next_button = browser.links.find_by_partial_text("Next")
    if next_button:
        next_button.click()
    else:
        break

# Convert the list to a DataFrame
df = pd.DataFrame(injury_table, columns=headers)
df
# Out:
#                  Name Team     Pos Injury / Surgery Date  \
# 0        Chris Martin  BOS      RP               Jun '24
# 1      Walker Buehler  LAD      SP              08/23/22
# 2           Shane Baz  TBR      SP              09/28/22
# 3     Lucas Gilbreath  COL      RP              03/14/23
# 4        Cade Cavalli  WSN      SP              03/22/23
# ..                ...  ...     ...                   ...
# 678   Hunter Stratton  PIT      RP              08/26/24
# 679  Michael Lorenzen  KCR      SP              08/27/24
# 680       Jorge Mateo  BAL  INF/OF              08/28/24
# 681    David Hamilton  BOS     INF              08/28/24
# 682    Marco Gonzales  PIT      SP               Sep '24
#
#                            Injury / Surgery     Status IL Retro Date  \
# 0                                   Anxiety  Activated      06/02/24
# 1                        Tommy John surgery  Activated      03/17/24
# 2                        Tommy John surgery  Activated      03/25/24
# 3                        Tommy John surgery  Activated      03/25/24
# 4                        Tommy John surgery  60-Day IL      03/28/24
# ..                                      ...        ...           ...
# 678  Knee surgery (ruptured patella tendon)  60-Day IL      08/25/24
# 679                      Strained hamstring  15-Day IL      08/28/24
# 680          Elbow surgery (internal brace)  60-Day IL      07/24/24
# 681           Fractured finger (left index)  10-Day IL      08/29/24
# 682                   Flexor tendon surgery  60-Day IL      08/09/24
#
#     Eligible to Return Return Date                 Latest Update
# 0             06/17/24    06/18/24                     Activated
# 1             04/07/24    05/06/24                     Activated
# 2             04/09/24    05/23/24                     Activated
# 3             05/24/24    08/16/24                     Activated
# 4             05/27/24                   No timetable for return
# ..                 ...         ...                           ...
# 678           10/24/24                       Out for 2024 season
# 679           09/12/24                   No timetable for return
# 680           09/22/24                       Out for 2024 season
# 681           09/08/24              Questionable for 2024 season
# 682           10/08/24                       Out for 2024 season
#
# [683 rows x 10 columns]

# %%
df
# Out:
#                  Name Team     Pos Injury / Surgery Date  \
# 0        Chris Martin  BOS      RP               Jun '24
# 1      Walker Buehler  LAD      SP              08/23/22
# 2           Shane Baz  TBR      SP              09/28/22
# 3     Lucas Gilbreath  COL      RP              03/14/23
# 4        Cade Cavalli  WSN      SP              03/22/23
# ..                ...  ...     ...                   ...
# 678   Hunter Stratton  PIT      RP              08/26/24
# 679  Michael Lorenzen  KCR      SP              08/27/24
# 680       Jorge Mateo  BAL  INF/OF              08/28/24
# 681    David Hamilton  BOS     INF              08/28/24
# 682    Marco Gonzales  PIT      SP               Sep '24
#
#                            Injury / Surgery     Status IL Retro Date  \
# 0                                   Anxiety  Activated      06/02/24
# 1                        Tommy John surgery  Activated      03/17/24
# 2                        Tommy John surgery  Activated      03/25/24
# 3                        Tommy John surgery  Activated      03/25/24
# 4                        Tommy John surgery  60-Day IL      03/28/24
# ..                                      ...        ...           ...
# 678  Knee surgery (ruptured patella tendon)  60-Day IL      08/25/24
# 679                      Strained hamstring  15-Day IL      08/28/24
# 680          Elbow surgery (internal brace)  60-Day IL      07/24/24
# 681           Fractured finger (left index)  10-Day IL      08/29/24
# 682                   Flexor tendon surgery  60-Day IL      08/09/24
#
#     Eligible to Return Return Date                 Latest Update
# 0             06/17/24    06/18/24                     Activated
# 1             04/07/24    05/06/24                     Activated
# 2             04/09/24    05/23/24                     Activated
# 3             05/24/24    08/16/24                     Activated
# 4             05/27/24                   No timetable for return
# ..                 ...         ...                           ...
# 678           10/24/24                       Out for 2024 season
# 679           09/12/24                   No timetable for return
# 680           09/22/24                       Out for 2024 season
# 681           09/08/24              Questionable for 2024 season
# 682           10/08/24                       Out for 2024 season
#
# [683 rows x 10 columns]

# %%
browser.quit()

# %%
df.to_csv("injury_report_24.csv")
