# %%
from splinter import Browser
from bs4 import BeautifulSoup as soup

# %%
browser = Browser("chrome")

# %%
url = "https://www.fangraphs.com/roster-resource/injury-report?groupby=all&timeframe=all&season=2020"

# %%
browser.visit(url)

# %%
html = browser.html

# %%
html_soup = soup(html, "html.parser")

# %%
browser.links.find_by_partial_text("Single Grid").click()

# %%
dropdown = browser.find_by_tag('select')

# %%
dropdown.select_by_text('Infinity')

# %%
tables = html_soup.find_all('table')

# %%
len(tables)
# Out:
# 16

# %%
rows = tables[15].find_all('tr')

# %%
headers = [x.text for x in rows[0].find_all('th')]

# %%
headers
# Out:
# ['Name',
#  'Team',
#  'Pos',
#  'Injury / Surgery Date',
#  'Injury / Surgery',
#  'Status',
#  'IL Retro Date',
#  'Eligible to Return',
#  'Return Date',
#  'Latest Update']

# %%
injury_table = []
for x in rows[1:]:
    injury_table.append([every_value.text for every_value in x.find_all("td")])

# %%
import pandas as pd
df = pd.DataFrame(injury_table, columns=headers)

# %%
# Initialize the DataFrame list
injury_table = []
# Loop through all pages
while True:
    # Parse the HTML
    html = browser.html
    html_soup = soup(html, "html.parser")
    
    # Find the table and rows
    tables = html_soup.find_all('table')
    rows = tables[15].find_all('tr')  # Adjust the index if necessary
    
    # Extract headers and data
    if len(injury_table) == 0:
        headers = [x.text for x in rows[0].find_all('th')]
    
    for row in rows[1:]:
        injury_table.append([val.text for val in row.find_all("td")])
    
    # Check if there's a "Next" button and click it, otherwise break
    next_button = browser.links.find_by_partial_text("Next")
    if next_button:
        next_button.click()
    else:
        break

# Convert the list to a DataFrame
df = pd.DataFrame(injury_table, columns=headers)
df
# Out:
#                   Name Team Pos Injury / Surgery Date  \
# 0       Silvino Bracho  ARI  RP              03/13/19
# 1       Michael Fulmer  DET  SP              03/27/19
# 2    Anderson Espinoza  SDP  SP              04/22/19
# 3         Carlos Rodón  CHW  SP              05/15/19
# 4        Corbin Martin  ARI  SP              07/03/19
# ..                 ...  ...  ..                   ...
# 525         David Dahl  COL  OF              09/29/20
# 526        Bryan Abreu  HOU  RP              09/29/20
# 527   Justin Verlander  HOU  SP              09/30/20
# 528          Ken Giles  TOR  RP              09/30/20
# 529       Brad Peacock  HOU  RP              10/06/20
#
#                   Injury / Surgery         Status IL Retro Date  \
# 0               Tommy John surgery  Active roster      07/20/20
# 1               Tommy John surgery  Active roster
# 2               Tommy John surgery      45-Day IL      02/12/20
# 3               Tommy John surgery                     07/20/20
# 4               Tommy John surgery      45-Day IL      07/20/20
# ..                             ...            ...           ...
# 525               Shoulder surgery      45-Day IL      09/21/20
# 526                    Undisclosed      45-Day IL      09/29/20
# 527             Tommy John surgery      10-Day IL      07/25/20
# 528             Tommy John surgery      10-Day IL      09/16/20
# 529  Arthroscopic shoulder surgery      10-Day IL      09/15/20
#
#     Eligible to Return Return Date            Latest Update
# 0             09/03/20    09/25/20                Activated
# 1                         07/23/20                Activated
# 2             06/30/20    09/28/20      Out for 2020 season
# 3             07/30/20    07/24/20                Activated
# 4             09/03/20    09/28/20      Out for 2020 season
# ..                 ...         ...                      ...
# 525           11/05/20    09/28/20      Out for 2020 season
# 526           11/13/20    09/28/20      Out for 2020 season
# 527           08/04/20    09/28/20      Out for 2020 season
# 528           09/26/20    09/28/20      Out for 2020 season
# 529           09/25/20    09/28/20  No timetable for return
#
# [530 rows x 10 columns]

# %%
df
# Out:
#                   Name Team Pos Injury / Surgery Date  \
# 0       Silvino Bracho  ARI  RP              03/13/19
# 1       Michael Fulmer  DET  SP              03/27/19
# 2    Anderson Espinoza  SDP  SP              04/22/19
# 3         Carlos Rodón  CHW  SP              05/15/19
# 4        Corbin Martin  ARI  SP              07/03/19
# ..                 ...  ...  ..                   ...
# 525         David Dahl  COL  OF              09/29/20
# 526        Bryan Abreu  HOU  RP              09/29/20
# 527   Justin Verlander  HOU  SP              09/30/20
# 528          Ken Giles  TOR  RP              09/30/20
# 529       Brad Peacock  HOU  RP              10/06/20
#
#                   Injury / Surgery         Status IL Retro Date  \
# 0               Tommy John surgery  Active roster      07/20/20
# 1               Tommy John surgery  Active roster
# 2               Tommy John surgery      45-Day IL      02/12/20
# 3               Tommy John surgery                     07/20/20
# 4               Tommy John surgery      45-Day IL      07/20/20
# ..                             ...            ...           ...
# 525               Shoulder surgery      45-Day IL      09/21/20
# 526                    Undisclosed      45-Day IL      09/29/20
# 527             Tommy John surgery      10-Day IL      07/25/20
# 528             Tommy John surgery      10-Day IL      09/16/20
# 529  Arthroscopic shoulder surgery      10-Day IL      09/15/20
#
#     Eligible to Return Return Date            Latest Update
# 0             09/03/20    09/25/20                Activated
# 1                         07/23/20                Activated
# 2             06/30/20    09/28/20      Out for 2020 season
# 3             07/30/20    07/24/20                Activated
# 4             09/03/20    09/28/20      Out for 2020 season
# ..                 ...         ...                      ...
# 525           11/05/20    09/28/20      Out for 2020 season
# 526           11/13/20    09/28/20      Out for 2020 season
# 527           08/04/20    09/28/20      Out for 2020 season
# 528           09/26/20    09/28/20      Out for 2020 season
# 529           09/25/20    09/28/20  No timetable for return
#
# [530 rows x 10 columns]

# %%
browser.quit()

# %%
df.to_csv("injury_report_20.csv")
