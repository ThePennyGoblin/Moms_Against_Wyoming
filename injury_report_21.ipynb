# %%
from splinter import Browser
from bs4 import BeautifulSoup as soup

# %%
browser = Browser("chrome")

# %%
url = "https://www.fangraphs.com/roster-resource/injury-report?groupby=all&timeframe=all&season=2021"

# %%
browser.visit(url)

# %%
html = browser.html

# %%
html_soup = soup(html, "html.parser")

# %%
browser.links.find_by_partial_text("Single Grid").click()

# %%
dropdown = browser.find_by_tag('select')

# %%
dropdown.select_by_text('Infinity')

# %%
tables = html_soup.find_all('table')

# %%
len(tables)
# Out:
# 16

# %%
rows = tables[15].find_all('tr')

# %%
headers = [x.text for x in rows[0].find_all('th')]

# %%
headers
# Out:
# ['Name',
#  'Team',
#  'Pos',
#  'Injury / Surgery Date',
#  'Injury / Surgery',
#  'Status',
#  'IL Retro Date',
#  'Eligible to Return',
#  'Return Date',
#  'Latest Update']

# %%
injury_table = []
for x in rows[1:]:
    injury_table.append([every_value.text for every_value in x.find_all("td")])

# %%
import pandas as pd
df = pd.DataFrame(injury_table, columns=headers)

# %%
# Initialize the DataFrame list
injury_table = []
# Loop through all pages
while True:
    # Parse the HTML
    html = browser.html
    html_soup = soup(html, "html.parser")
    
    # Find the table and rows
    tables = html_soup.find_all('table')
    rows = tables[15].find_all('tr')  # Adjust the index if necessary
    
    # Extract headers and data
    if len(injury_table) == 0:
        headers = [x.text for x in rows[0].find_all('th')]
    
    for row in rows[1:]:
        injury_table.append([val.text for val in row.find_all("td")])
    
    # Check if there's a "Next" button and click it, otherwise break
    next_button = browser.links.find_by_partial_text("Next")
    if next_button:
        next_button.click()
    else:
        break

# Convert the list to a DataFrame
df = pd.DataFrame(injury_table, columns=headers)
df
# Out:
#                   Name Team  Pos Injury / Surgery Date  \
# 0
# 1          Jean Segura  PHI  INF              06/15/02
# 2            Seth Lugo  NYM   RP              02/16/20
# 3        Luis Severino  NYY   SP              02/27/20
# 4          Brock Burke  TEX   SP              02/28/20
# ...                ...  ...  ...                   ...
# 1216         Joe Smith  SEA   RP              10/02/21
# 1217        J.D. Davis  NYM   3B              10/05/21
# 1218  Garrett Richards  BOS   RP              10/07/21
# 1219       Jorge Soler  ATL   OF              10/12/21
# 1220         Joe Kelly  LAD   RP              10/21/21
#
#                            Injury / Surgery     Status IL Retro Date  \
# 0
# 1                            Strained groin  Activated      06/16/21
# 2                 Elbow surgery (bone spur)  Activated      03/29/21
# 3                        Tommy John surgery  Activated      03/29/21
# 4     Shoulder surgery (labrum debridement)  Activated      03/29/21
# ...                                     ...        ...           ...
# 1216                    COVID-19 (protocol)   CV-19 IL      10/02/21
# 1217           Hand surgery (torn ligament)  10-Day IL      09/23/21
# 1218                     Strained hamstring  10-Day IL      10/08/21
# 1219                               COVID-19  Activated      10/12/21
# 1220                        Strained biceps  10-Day IL      10/22/21
#
#      Eligible to Return Return Date            Latest Update
# 0
# 1              06/26/21    06/29/21                Activated
# 2              05/28/21    05/31/21                Activated
# 3              05/28/21    09/20/21                Activated
# 4              04/08/21    04/24/21                Activated
# ...                 ...         ...                      ...
# 1216           10/03/21              No timetable for return
# 1217           10/03/21                  Out for 2021 season
# 1218           10/18/21              No timetable for return
# 1219           10/13/21    10/21/21                Activated
# 1220           11/01/21              No timetable for return
#
# [1221 rows x 10 columns]

# %%
df
# Out:
#                   Name Team  Pos Injury / Surgery Date  \
# 0
# 1          Jean Segura  PHI  INF              06/15/02
# 2            Seth Lugo  NYM   RP              02/16/20
# 3        Luis Severino  NYY   SP              02/27/20
# 4          Brock Burke  TEX   SP              02/28/20
# ...                ...  ...  ...                   ...
# 1216         Joe Smith  SEA   RP              10/02/21
# 1217        J.D. Davis  NYM   3B              10/05/21
# 1218  Garrett Richards  BOS   RP              10/07/21
# 1219       Jorge Soler  ATL   OF              10/12/21
# 1220         Joe Kelly  LAD   RP              10/21/21
#
#                            Injury / Surgery     Status IL Retro Date  \
# 0
# 1                            Strained groin  Activated      06/16/21
# 2                 Elbow surgery (bone spur)  Activated      03/29/21
# 3                        Tommy John surgery  Activated      03/29/21
# 4     Shoulder surgery (labrum debridement)  Activated      03/29/21
# ...                                     ...        ...           ...
# 1216                    COVID-19 (protocol)   CV-19 IL      10/02/21
# 1217           Hand surgery (torn ligament)  10-Day IL      09/23/21
# 1218                     Strained hamstring  10-Day IL      10/08/21
# 1219                               COVID-19  Activated      10/12/21
# 1220                        Strained biceps  10-Day IL      10/22/21
#
#      Eligible to Return Return Date            Latest Update
# 0
# 1              06/26/21    06/29/21                Activated
# 2              05/28/21    05/31/21                Activated
# 3              05/28/21    09/20/21                Activated
# 4              04/08/21    04/24/21                Activated
# ...                 ...         ...                      ...
# 1216           10/03/21              No timetable for return
# 1217           10/03/21                  Out for 2021 season
# 1218           10/18/21              No timetable for return
# 1219           10/13/21    10/21/21                Activated
# 1220           11/01/21              No timetable for return
#
# [1221 rows x 10 columns]

# %%
browser.quit()

# %%
df.to_csv("injury_report_21.csv")
