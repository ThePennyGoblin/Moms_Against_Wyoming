# %%
from splinter import Browser
from bs4 import BeautifulSoup as soup

# %%
browser = Browser("chrome")

# %%
url = "https://www.fangraphs.com/roster-resource/injury-report?groupby=all&timeframe=all&season=2023"

# %%
browser.visit(url)

# %%
html = browser.html

# %%
html_soup = soup(html, "html.parser")

# %%
browser.links.find_by_partial_text("Single Grid").click()

# %%
dropdown = browser.find_by_tag('select')

# %%
dropdown.select_by_text('Infinity')

# %%
tables = html_soup.find_all('table')

# %%
len(tables)
# Out:
# 16

# %%
rows = tables[15].find_all('tr')

# %%
headers = [x.text for x in rows[0].find_all('th')]

# %%
headers
# Out:
# ['Name',
#  'Team',
#  'Pos',
#  'Injury / Surgery Date',
#  'Injury / Surgery',
#  'Status',
#  'IL Retro Date',
#  'Eligible to Return',
#  'Return Date',
#  'Latest Update']

# %%
injury_table = []
for x in rows[1:]:
    injury_table.append([every_value.text for every_value in x.find_all("td")])

# %%
import pandas as pd
df = pd.DataFrame(injury_table, columns=headers)

# %%
# Initialize the DataFrame list
injury_table = []
# Loop through all pages
while True:
    # Parse the HTML
    html = browser.html
    html_soup = soup(html, "html.parser")
    
    # Find the table and rows
    tables = html_soup.find_all('table')
    rows = tables[15].find_all('tr')  # Adjust the index if necessary
    
    # Extract headers and data
    if len(injury_table) == 0:
        headers = [x.text for x in rows[0].find_all('th')]
    
    for row in rows[1:]:
        injury_table.append([val.text for val in row.find_all("td")])
    
    # Check if there's a "Next" button and click it, otherwise break
    next_button = browser.links.find_by_partial_text("Next")
    if next_button:
        next_button.click()
    else:
        break

# Convert the list to a DataFrame
df = pd.DataFrame(injury_table, columns=headers)
df
# Out:
#                   Name Team Pos Injury / Surgery Date  \
# 0    Stephen Strasburg  WSN  SP              07/28/21
# 1         Jimmy Nelson  LAD  RP               Aug '21
# 2      Chris Rodriguez  LAA  SP               Oct '21
# 3      Garrett Crochet  CHW  RP              04/05/22
# 4         Luke Jackson  SFG  RP              04/13/22
# ..                 ...  ...  ..                   ...
# 851   Jackson Stephens  ATL  RP              09/29/23
# 852       Nico Hoerner  CHC  2B              09/29/23
# 853     Dallas Keuchel  MIN  SP              09/30/23
# 854    Sandy Alcantara  MIA  SP              10/06/23
# 855     Félix Bautista  BAL  RP              10/09/23
#
#                      Injury / Surgery     Status IL Retro Date  \
# 0    Thoracic outlet syndrome surgery  60-Day IL      03/27/23
# 1                  Tommy John surgery  60-Day IL      03/27/23
# 2                    Shoulder surgery  60-Day IL      03/27/23
# 3                  Tommy John surgery  Activated      03/27/23
# 4                  Tommy John surgery  Activated      03/27/23
# ..                                ...        ...           ...
# 851                Elbow inflammation  15-Day IL      09/30/23
# 852                    Knee contusion  15-Day IL      09/30/23
# 853                     Strained calf  15-Day IL      10/01/23
# 854                Tommy John surgery  15-Day IL      09/04/23
# 855                Tommy John surgery  15-Day IL      08/26/23
#
#     Eligible to Return Return Date                 Latest Update
# 0             05/26/23                   No timetable for return
# 1             05/26/23                   Rehab assignment (7/18)
# 2             05/26/23                       Out for 2023 season
# 3             04/11/23    05/16/23                     Activated
# 4             05/26/23    05/30/23                     Activated
# ..                 ...         ...                           ...
# 851           10/15/23              Questionable for 2023 season
# 852           10/10/23                       Out for 2023 season
# 853           10/16/23              Questionable for 2023 season
# 854           09/19/23                       Out for 2023 season
# 855           09/10/23                       Out for 2023 season
#
# [856 rows x 10 columns]

# %%
df
# Out:
#                   Name Team Pos Injury / Surgery Date  \
# 0    Stephen Strasburg  WSN  SP              07/28/21
# 1         Jimmy Nelson  LAD  RP               Aug '21
# 2      Chris Rodriguez  LAA  SP               Oct '21
# 3      Garrett Crochet  CHW  RP              04/05/22
# 4         Luke Jackson  SFG  RP              04/13/22
# ..                 ...  ...  ..                   ...
# 851   Jackson Stephens  ATL  RP              09/29/23
# 852       Nico Hoerner  CHC  2B              09/29/23
# 853     Dallas Keuchel  MIN  SP              09/30/23
# 854    Sandy Alcantara  MIA  SP              10/06/23
# 855     Félix Bautista  BAL  RP              10/09/23
#
#                      Injury / Surgery     Status IL Retro Date  \
# 0    Thoracic outlet syndrome surgery  60-Day IL      03/27/23
# 1                  Tommy John surgery  60-Day IL      03/27/23
# 2                    Shoulder surgery  60-Day IL      03/27/23
# 3                  Tommy John surgery  Activated      03/27/23
# 4                  Tommy John surgery  Activated      03/27/23
# ..                                ...        ...           ...
# 851                Elbow inflammation  15-Day IL      09/30/23
# 852                    Knee contusion  15-Day IL      09/30/23
# 853                     Strained calf  15-Day IL      10/01/23
# 854                Tommy John surgery  15-Day IL      09/04/23
# 855                Tommy John surgery  15-Day IL      08/26/23
#
#     Eligible to Return Return Date                 Latest Update
# 0             05/26/23                   No timetable for return
# 1             05/26/23                   Rehab assignment (7/18)
# 2             05/26/23                       Out for 2023 season
# 3             04/11/23    05/16/23                     Activated
# 4             05/26/23    05/30/23                     Activated
# ..                 ...         ...                           ...
# 851           10/15/23              Questionable for 2023 season
# 852           10/10/23                       Out for 2023 season
# 853           10/16/23              Questionable for 2023 season
# 854           09/19/23                       Out for 2023 season
# 855           09/10/23                       Out for 2023 season
#
# [856 rows x 10 columns]

# %%
browser.quit()

# %%
df.to_csv("injury_report_23.csv")
